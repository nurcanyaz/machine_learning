# %%
from google.colab import files
uploaded=files.upload()
# Out:
#      <input type="file" id="files-98ff727c-b55a-43d6-ab04-7be229bd5d39" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-98ff727c-b55a-43d6-ab04-7be229bd5d39">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
import io

veri=pd.read_csv(io.BytesIO(uploaded['MOVIES.csv']))

# %%
veri.head()
# Out:
#    adult  belongs_to_collection    budget  original_language  original_title  \
# 0  False                   1542  30000000                 17           36543
# 1  False                   1673  65000000                 17           16085
# 2  False                    528         0                 17           12672
# 3  False                   1673  16000000                 17           38147
# 4  False                    433         0                 17           10729
#
#    overview  popularity  release_date      revenue  runtime  ...  vote_count  \
# 0     26425   21.946943         10645  373554033.0     81.0  ...      5415.0
# 1     42527   17.015539         10676  262797249.0    104.0  ...      2413.0
# 2      3121   11.712900         10681          0.0    101.0  ...        92.0
# 3     15727    3.859495         10681   81452156.0    127.0  ...        34.0
# 4     25831    8.387519         10478   76578911.0    106.0  ...       173.0
#
# ...

# %%
veri.describe()
# Out:
#              budget    popularity       revenue      runtime  vote_average  \
# count  4.498500e+04  44985.000000  4.498500e+04  44985.00000  44985.000000
# mean   4.265097e+06      2.938571  1.132230e+07     93.74287      5.623861
# std    1.750944e+07      6.024450  6.466000e+07     38.89765      1.915941
# min    0.000000e+00      0.000000  0.000000e+00      0.00000      0.000000
# 25%    0.000000e+00      0.390902  0.000000e+00     85.00000      5.000000
# 50%    0.000000e+00      1.135639  0.000000e+00     95.00000      6.000000
# 75%    0.000000e+00      3.728260  0.000000e+00    107.00000      6.800000
# max    3.800000e+08    547.488298  2.787965e+09   1256.00000     10.000000
#
#          vote_count          year
# count  44985.000000  44985.000000
# mean     110.928154   1988.367189
# std      493.782124     86.288053
# min        0.000000      0.000000
# 25%        3.000000   1978.000000
# 50%       10.000000   2001.000000
# 75%       35.000000   2010.000000
# ...

# %%
veri.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 44985 entries, 0 to 44984
# Data columns (total 23 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   adult                  44985 non-null  bool
#  1   belongs_to_collection  44985 non-null  object
#  2   budget                 44985 non-null  int64
#  3   original_language      44985 non-null  object
#  4   original_title         44985 non-null  object
#  5   overview               44985 non-null  object
#  6   popularity             44985 non-null  float64
#  7   release_date           44985 non-null  object
#  8   revenue                44985 non-null  float64
#  9   runtime                44985 non-null  float64
#  10  tagline                44985 non-null  object
#  11  title                  44985 non-null  object
#  12  vote_average           44985 non-null  float64
#  13  vote_count             44985 non-null  float64
# ...

# %%
veri.isna().sum()
# Out:
# adult                    0
# belongs_to_collection    0
# budget                   0
# original_language        0
# original_title           0
# overview                 0
# popularity               0
# release_date             0
# revenue                  0
# runtime                  0
# tagline                  0
# title                    0
# vote_average             0
# vote_count               0
# languages                0
# day_of_week              0
# month                    0
# season                   0
# year                     0
# has_homepage             0
# genre                    0
# companies                0
# countries                0
# dtype: int64

# %%
veri.dropna(inplace=True)

# %%
from sklearn.preprocessing import LabelEncoder

label_encoder= LabelEncoder()

for column in veri.columns:
  if veri[column].dtype == 'object':
    veri[column] = label_encoder.fit_transform(veri[column])

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from xgboost import XGBClassifier
from sklearn.svm import SVC

log_reg = LogisticRegression()
decision_tree = DecisionTreeClassifier()
random_forest = RandomForestClassifier()
k_neighbors = KNeighborsClassifier()
xgb_classifier = XGBClassifier()
svc = SVC()

# %%
from sklearn.metrics import classification_report
from sklearn.model_selection import train_test_split
import numpy as np

x = veri.drop(columns=['popularity'])
y = veri['popularity']

median_y = np.median(y)
y = np.where(y > median_y, 1, 0)

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.25, random_state=42)

# %%
for ad, siniflandirici in {"Logistic Regression": log_reg, "Decision Tree Classifier": decision_tree,
                           "Random Forest Classifier": random_forest,
                           "KNeighbors Classifier": k_neighbors,
                           "XGB Classifier": xgb_classifier, "SVC": svc}.items():
    siniflandirici.fit(x_train, y_train)
    y_pred = siniflandirici.predict(x_test)
    rapor = classification_report(y_test, y_pred)
    print(ad, ":\n", rapor)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Logistic Regression :
#                precision    recall  f1-score   support
#
#            0       0.65      0.80      0.72      5600
#            1       0.74      0.57      0.65      5647
#
#     accuracy                           0.68     11247
#    macro avg       0.69      0.69      0.68     11247
# weighted avg       0.69      0.68      0.68     11247
#
# Decision Tree Classifier :
#                precision    recall  f1-score   support
#
# ...
